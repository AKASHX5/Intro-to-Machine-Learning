# %%
import numpy as np
import pandas as pd
import sys
import matplotlib.pyplot as plt
import statsmodels.api as sm
from pandas.tools.plotting import scatter_matrix
data="/Users/akash/Documents/dataset/Ndata.csv"
names=['UserId','Purpose','Type','Duration','Budget','No_of_people','Hotel_Id','Rating']
data2 = pandas.read_csv(data, names=names)
datay=data2.drop(data2.index[0])
datay.head()
scatter_matrix(datay[names], alpha=0.4)
#scatter_matrix(datay)
print "names",names
plt.show()
# Out:
# names ['UserId', 'Purpose', 'Type', 'Duration', 'Budget', 'No_of_people', 'Hotel_Id', 'Rating']

# %%
import plotly
plotly.__version__
# Out:
# '2.0.6'

# %%
#Greys, YlGnBu, Greens, YlOrRd, Bluered, RdBu, Reds, Blues, Picnic, Rainbow, Portland, Jet, Hot, Blackbody, Earth, Electric, Viridis
import plotly.plotly as py
import plotly.graph_objs as go
import pandas as pd 

from matplotlib import style 
style.use('ggplot')
import numpy as np
from sklearn.cluster import KMeans

# df = pd.read_csv("/Users/akash/Documents/dataset/Ndata.csv")
# df.drop(['UserId'])

X=np.array([[1,2],
            [1.5,1.8],
            [5,8],
            [8,8],
            [1,0.6],
             [9,11]])
# plt.scatter(X[:,0],X[:,1],s=150)
# plt.show()



clf = KMeans(n_clusters=2)
clf.fit(X)

centroids=clf.cluster_centers_
labels=clf.labels_


colors=["g.","r.","c.","k.","o."]
for i in range(len(X)):
    plt.plot(X[i][0],X[i][1],colors[labels[i]],markersize=10)
plt.scatter(centroids[:,0],centroids[:,1],marker='x',s=150,linewidths=5)
plt.show()
